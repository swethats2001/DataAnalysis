# %%
#Import libraries
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %%
#Reading data set
df=pd.read_csv("myexcel.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df["Height"]
# Out:
# 0      06-Feb
# 1      06-Jun
# 2      06-May
# 3      06-May
# 4      06-Oct
#         ...
# 453    06-Mar
# 454    06-Jan
# 455    07-Mar
# 456       7-0
# 457    07-Mar
# Name: Height, Length: 458, dtype: object

# %%
# Copying data to work in that copied data
df2=df.copy()
df2
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# to deactivate warnings
import warnings
import sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %% [markdown]
# # Preprocessing:
# Correct the data in the "height" column by replacing it with random numbers between 150 and 180. Ensure data consistency and integrity before proceeding with analysis. (1 mark)

# %%
df2["Height"]=np.random.randint(150,180,size=len(df2))

# %%
df2["Height"]
# Out:
# 0      153
# 1      169
# 2      156
# 3      175
# 4      166
#       ...
# 453    177
# 454    165
# 455    173
# 456    164
# 457    165
# Name: Height, Length: 458, dtype: int32

# %%
df2
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     153     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     169     235
# 2     John Holland  Boston Celtics      30       SG   27     156     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     175     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     166     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     177     203
# 454      Raul Neto       Utah Jazz      25       PG   24     165     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     173     256
# 456    Jeff Withey       Utah Jazz      24        C   26     164     231
# 457       Priyanka       Utah Jazz      34        C   25     165     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # Analysis Tasks:
# 1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees. (2 marks)

# %%
#Identify distinct team 
df2["Team"].unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
emp = df2['Team'].value_counts()
percentage_split = (emp / len(df2)) * 100
result = pd.DataFrame({'Team': emp.index, 
                       'Count': emp.values, 
                       'Percentage': percentage_split.values})
print(result)
# Out:
#                       Team  Count  Percentage
# 0     New Orleans Pelicans     19    4.148472
# 1        Memphis Grizzlies     18    3.930131
# 2                Utah Jazz     16    3.493450
# 3          New York Knicks     16    3.493450
# 4          Milwaukee Bucks     16    3.493450
# 5            Brooklyn Nets     15    3.275109
# 6   Portland Trail Blazers     15    3.275109
# 7    Oklahoma City Thunder     15    3.275109
# 8           Denver Nuggets     15    3.275109
# 9       Washington Wizards     15    3.275109
# 10              Miami Heat     15    3.275109
# 11       Charlotte Hornets     15    3.275109
# 12           Atlanta Hawks     15    3.275109
# 13       San Antonio Spurs     15    3.275109
# 14         Houston Rockets     15    3.275109
# 15          Boston Celtics     15    3.275109
# 16          Indiana Pacers     15    3.275109
# 17         Detroit Pistons     15    3.275109
# 18     Cleveland Cavaliers     15    3.275109
# ...

# %% [markdown]
# 2. Segregate employees based on their positions within the company.

# %%
result = df2['Position'].value_counts()
print(result)
plt.figure(figsize=(8, 5))
colors = ["#ff9999", "#66b3ff", "#99ff99", "#ffcc99", "#c2c2f0", "#ffb3e6"]
plt.pie(result.values, labels=result.index, autopct='%1.1f%%', colors=colors, startangle=140)
plt.title("Distribution of Employees by Position")
plt.show()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %% [markdown]
# * Method : The total number of employees are found with respect to the position using value_counts() method grouped by position.
# * A pie chart is plotted to show the insights.
# * Findings/Insigts : From the above pie chart it is visible that the highest number of employees are present in 'SG' position(22.3%, 102 employees) and lowest in 'C' position(17.2%, 79 employees).

# %% [markdown]
# 3. Identify the predominant age group among employees. (2 marks)

# %%
age_groups = pd.cut(df2['Age'], 
                    bins=[20, 25, 30, 35, 40, 45, 50], 
                    labels=["20-25", "25-30", "30-35", "35-40", "40-45", "45-50"])
age_group_distribution = age_groups.value_counts()
predominant_age_group = age_group_distribution.idxmax()
print(age_group_distribution)
plt.figure(figsize=(10, 6))
age_group_distribution.plot(kind='bar', color='green')
plt.xlabel("Age Groups")
plt.ylabel("Number of Employees")
plt.title("Age Group Distribution")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Age
# 20-25    179
# 25-30    167
# 30-35     68
# 35-40     23
# 40-45      0
# 45-50      0
# Name: count, dtype: int64

# %% [markdown]
# * Method:Age group is found using 'cut()' method to segment and sort data values into bins.
# * age_group_distribution and predominant_age_group is found using 'value_counts()' of age_groups and 'idxmax()' of age_group_distribution respectievly.
# * A bar chart is plotted to find Age Group Distribution.
# * Findings/Insigts: Age group '20-25' has highest number of employees(179).

# %% [markdown]
# 4. Discover which team and position have the highest salary expenditure. (2 marks)

# %%
salexp = df.groupby('Team')['Salary'].sum()
highest_salary = salexp.idxmax()
salexpos = df.groupby('Position')['Salary'].sum()
highest_salary_position = salexpos.idxmax()

plt.figure(figsize=(15, 5))
plt.plot(salexp.index, salexp.values, marker='o', linestyle='-', color='b', label="Team Salary Expenditure")
plt.xlabel("Team")
plt.ylabel("Total Salary Expenditure")
plt.title("Salary Expenditure by Team")
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(salexpos.index, salexpos.values, marker='o', linestyle='-', color='g', label="Position Salary Expenditure")
plt.xlabel("Position")
plt.ylabel("Total Salary Expenditure")
plt.title("Salary Expenditure by Position")
plt.legend()
plt.show()

# %% [markdown]
# * Method:Highest salary with respect to position and team are found using 'sum()' and 'idmax()' functions.
# * A line chart is plotted to visualize the findings.
# * Findings/Insigts: Team with highest salary expenditure: Cleveland Cavaliers and Position with highest salary expenditure: C

# %% [markdown]
# 5. Investigate if there's any correlation between age and salary, and represent it visually. (2 marks)

# %%
correlation = df['Age'].corr(df['Salary'])

plt.figure(figsize=(8, 5))
sns.scatterplot(x=df2['Age'],y=df2['Salary'],hue=df2['Age'],data=df2)
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Correlation between Age and Salary")
plt.show()

print("Correlation between Age and Salary:", correlation)
# Out:
# Correlation between Age and Salary: 0.21400941226570971

# %% [markdown]
# * Method: Correlation between age and salary are found using 'corr()'
# * A scatterplot graph if used to represent the findings.
# * Findings/Insights:Correlation between Age and Salary is 0.21400941226570971
